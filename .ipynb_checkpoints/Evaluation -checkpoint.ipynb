# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd


from epftoolbox.data import read_data
from epftoolbox.evaluation import MAE, sMAPE, RMSE
from epftoolbox.models import LEAR

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

from datetime import datetime as dt

# %%
PJM = pd.read_csv('PJMeval.csv', index_col=[0])
NP = pd.read_csv('NPeval.csv', index_col=[0])
FR = pd.read_csv('FReval.csv', index_col=[0], parse_dates=[0])
NGBoost = pd.read_csv('forecast_ng.csv', index_col=[0])


df = pd.read_csv('df_test.csv', index_col=[0])

# %% [markdown]
# # PJM LEAR, DNN, NGBOOST

# %%
PJM
# Out:
#                   Real price      DNN 1      DNN 2      DNN 3      DNN 4  \
# 27/12/2016 00:00   19.113045  19.706123  19.040689  19.661985  18.857361
# 27/12/2016 01:00   18.042768  18.578808  18.628008  18.581722  17.804329
# 27/12/2016 02:00   17.587395  17.405716  17.954073  17.564003  16.387474
# 27/12/2016 03:00   17.399361  16.994461  17.322933  16.941095  15.673610
# 27/12/2016 04:00   17.804108  18.000519  18.452641  17.457172  15.920693
# ...                      ...        ...        ...        ...        ...
# 26/01/2017 19:00   32.532418  35.463852  34.982365  33.913315  33.568974
# 26/01/2017 20:00   32.359850  34.117020  32.247231  32.549648  33.142986
# 26/01/2017 21:00   27.024776  30.924381  29.068047  29.203970  30.024324
# 26/01/2017 22:00   25.084933  27.033443  26.138130  25.693201  26.761005
# 26/01/2017 23:00   23.213711  24.580513  23.537296  23.653360  24.919537
#
#                   DNN Ensemble  LEAR 56  LEAR 84  LEAR 1092  LEAR 1456  \
# 27/12/2016 00:00     19.316540  20.1291  20.7366    19.1060    18.9901
# 27/12/2016 01:00     18.398217  19.5229  19.5459    18.2766    18.4639
# 27/12/2016 02:00     17.327816  19.0085  18.9345    17.4325    17.5918
# 27/12/2016 03:00     16.733025  18.9757  19.2347    17.4400    17.5345
# 27/12/2016 04:00     17.457756  19.3679  19.8770    18.1750    18.1798
# ...                        ...      ...      ...        ...        ...
# 26/01/2017 19:00     34.482126  33.9588  33.4068    35.8747    36.8332
# 26/01/2017 20:00     33.014221  32.5864  31.9694    34.3195    34.9149
# 26/01/2017 21:00     29.805181  29.7851  28.7912    30.1627    30.5398
# 26/01/2017 22:00     26.406445  26.0611  24.7918    26.5028    26.8162
# 26/01/2017 23:00     24.172677  23.9410  23.5673    24.1160    24.5428
#
#                   LEAR Ensemble
# 27/12/2016 00:00      19.740450
# 27/12/2016 01:00      18.952325
# 27/12/2016 02:00      18.241825
# 27/12/2016 03:00      18.296225
# 27/12/2016 04:00      18.899925
# ...                         ...
# 26/01/2017 19:00      35.018375
# 26/01/2017 20:00      33.447550
# 26/01/2017 21:00      29.819700
# 26/01/2017 22:00      26.042975
# 26/01/2017 23:00      24.041775
#
# [744 rows x 11 columns]

# %%
PJM_DNN = PJM

# %%
PJM.drop(['DNN 2', 'DNN 3', 'DNN 4', 'DNN Ensemble', 'LEAR 84', 'LEAR 1092', 'LEAR 1456', 'LEAR Ensemble'], axis=1, inplace=True)
NP.drop(['DNN 2', 'DNN 3', 'DNN 4', 'DNN Ensemble', 'LEAR 84', 'LEAR 1092', 'LEAR 1456', 'LEAR Ensemble'], axis=1,  inplace=True)
FR.drop(['DNN 2', 'DNN 3', 'DNN 4', 'DNN Ensemble', 'LEAR 84', 'LEAR 1092', 'LEAR 1456', 'LEAR Ensemble'], axis=1,  inplace=True)

# %%
PJM
# Out:
#                   Real price      DNN 1  LEAR 56
# 27/12/2016 00:00   19.113045  19.706123  20.1291
# 27/12/2016 01:00   18.042768  18.578808  19.5229
# 27/12/2016 02:00   17.587395  17.405716  19.0085
# 27/12/2016 03:00   17.399361  16.994461  18.9757
# 27/12/2016 04:00   17.804108  18.000519  19.3679
# ...                      ...        ...      ...
# 26/01/2017 19:00   32.532418  35.463852  33.9588
# 26/01/2017 20:00   32.359850  34.117020  32.5864
# 26/01/2017 21:00   27.024776  30.924381  29.7851
# 26/01/2017 22:00   25.084933  27.033443  26.0611
# 26/01/2017 23:00   23.213711  24.580513  23.9410
#
# [744 rows x 3 columns]

# %% [markdown]
# ### PJM_LEAR_MAE_MAPE

# %%
MAE_PJM = pd.DataFrame(columns=['RMSE','MAE','sMAPE(%)'], index=PJM.index)
for date in PJM.index:
    MAE_PJM.loc[date]['RMSE'] = RMSE(pd.Series(PJM.loc[date]['LEAR 56']), pd.Series(PJM.loc[date]['Real price']))
    MAE_PJM.loc[date]['MAE'] = MAE(pd.Series(PJM.loc[date]['LEAR 56']), pd.Series(PJM.loc[date]['Real price']))
    MAE_PJM.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(PJM.loc[date]['LEAR 56']), pd.Series(PJM.loc[date]['Real price'])) * 100

# %%
MAE_PJM
# Out:
#                       RMSE       MAE  sMAPE(%)
# 27/12/2016 00:00  1.016055  1.016055  5.178387
# 27/12/2016 01:00  1.480132  1.480132  7.880238
# 27/12/2016 02:00  1.421105  1.421105  7.766472
# 27/12/2016 03:00  1.576339  1.576339  8.667141
# 27/12/2016 04:00  1.563792  1.563792  8.413815
# ...                    ...       ...       ...
# 26/01/2017 19:00  1.426382  1.426382  4.290437
# 26/01/2017 20:00   0.22655   0.22655  0.697654
# 26/01/2017 21:00  2.760324  2.760324  9.717761
# 26/01/2017 22:00  0.976167  0.976167  3.817176
# 26/01/2017 23:00  0.727289  0.727289  3.084693
#
# [744 rows x 3 columns]

# %%
print(f"Overall RMSE : {RMSE(PJM['LEAR 56'], PJM['Real price'])}")
# Out:
# Overall RMSE : 3.057569933417542

# %%
print(f"Overall MAE : {MAE(PJM['LEAR 56'], PJM['Real price'])}")
# Out:
# Overall MAE : 2.2324875712365593

# %%
print(f"Overall sMAPE : {sMAPE(PJM['LEAR 56'], PJM['Real price']) * 100}")
# Out:
# Overall sMAPE : 7.597143505568613

# %% [markdown]
# ### PJM_DNN_MAE_MAPE

# %%
MAE_PJM = pd.DataFrame(columns=['MAE','sMAPE(%)'], index=PJM.index)
for date in PJM.index:
    MAE_PJM.loc[date]['RMSE'] = RMSE(pd.Series(PJM.loc[date]['DNN 1']), pd.Series(PJM.loc[date]['Real price']))
    MAE_PJM.loc[date]['MAE'] = MAE(pd.Series(PJM.loc[date]['DNN 1']), pd.Series(PJM.loc[date]['Real price']))
    MAE_PJM.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(PJM.loc[date]['DNN 1']), pd.Series(PJM.loc[date]['Real price'])) * 100

# %%
print(f"Overall MAE : {MAE(PJM['DNN 1'], PJM['Real price'])}")
# Out:
# Overall MAE : 2.1765672896236556

# %%
print(f"Overall sMAPE : {sMAPE(PJM['DNN 1'], PJM['Real price']) * 100}")
# Out:
# Overall sMAPE : 7.50924188506638

# %%
print(f"Overall RMSE : {RMSE(PJM['DNN 1'], PJM['Real price'])}")
# Out:
# Overall RMSE : 2.929825690654638

# %% [markdown]
# ### PJM_NGBOOST_MAE_MAPE

# %%
NGB = pd.DataFrame(columns=['Predicted', 'Real Price'], index=pd.date_range(start=dt(2017, 12, 26, 0, 0, 0), end=dt(2018, 12, 24, 23, 0, 0), freq='H'))

# %%
temp = []
for _,row in enumerate(NGBoost.index):
    for value in NGBoost:
         temp.append(NGBoost.loc[row][value])

# %%
NGB['Predicted'] = temp

# %%
NGB.reset_index(inplace=True)
df.reset_index(inplace=True)
NGB['Real Price'] = df['Price']
NGB.set_index('index',inplace=True)
df.set_index('Date',inplace=True)

# %%
NGB = NGB[:30*24]

# %%
MAE_NGB = pd.DataFrame(columns=['MAE','sMAPE(%)'], index=NGB.index)
for date in NGB.index:
    #MAE_NGB.loc[date]['RMSE'] = RMSE(pd.Series(NGB.loc[date]['Predicted']), pd.Series(PJM.loc[date]['Real price']))
    MAE_NGB.loc[date]['MAE'] = MAE(pd.Series(NGB.loc[date]['Predicted']), pd.Series(NGB.loc[date]['Real Price']))
    MAE_NGB.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(NGB.loc[date]['Predicted']), pd.Series(NGB.loc[date]['Real Price'])) * 100

# %%
#NGBOOST PJM MAE
print(f"Overall MAE : {MAE(NGB['Predicted'], NGB['Real Price'])}")
# Out:
# Overall MAE : 10.582150308006632

# %%
#NGBOOST PJM MAPE
print(f"Overall sMAPE : {sMAPE(NGB['Predicted'], NGB['Real Price']) * 100} %")
# Out:
# Overall sMAPE : 23.33853202166183 %

# %% [markdown]
# # NP LEAR, DNN, NGBOOST

# %%
NP
# Out:
#                   Real price      DNN 1  LEAR 56
# 27/12/2016 00:00       24.08  24.530144  25.1290
# 27/12/2016 01:00       22.52  23.115845  24.2083
# 27/12/2016 02:00       20.13  22.563509  23.9289
# 27/12/2016 03:00       19.86  22.047380  23.4943
# 27/12/2016 04:00       20.09  23.055725  23.5104
# ...                      ...        ...      ...
# 26/01/2017 19:00       30.66  30.362480  30.3091
# 26/01/2017 20:00       29.85  29.554022  30.2290
# 26/01/2017 21:00       29.67  29.148659  29.6552
# 26/01/2017 22:00       29.05  28.654337  29.2686
# 26/01/2017 23:00       28.66  28.070572  28.9244
#
# [744 rows x 3 columns]

# %% [markdown]
# ### NP_LEAR_MAE_MAPE

# %%
 MAE_NP = pd.DataFrame(columns=['MAE','sMAPE(%)'], index=NP.index)
for date in NP.index:
    MAE_PJM.loc[date]['RMSE'] = RMSE(pd.Series(NP.loc[date]['LEAR 56']), pd.Series(NP.loc[date]['Real price']))
    MAE_NP.loc[date]['MAE'] = MAE(pd.Series(NP.loc[date]['LEAR 56']), pd.Series(NP.loc[date]['Real price']))
    MAE_NP.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(NP.loc[date]['LEAR 56']), pd.Series(NP.loc[date]['Real price'])) * 100

# %%
print(f"Overall MAE : {MAE(NP['LEAR 56'], NP['Real price'])}")
# Out:
# Overall MAE : 1.7682907258064515

# %%
print(f"Overall sMAPE : {sMAPE(NP['LEAR 56'], NP['Real price']) * 100}")
# Out:
# Overall sMAPE : 5.3357347320699935

# %%
print(f"Overall RMSE : {RMSE(NP['LEAR 56'], NP['Real price'])}")
# Out:
# Overall RMSE : 3.184784680917026

# %% [markdown]
# ### NP_DNN_MAE_MAPE

# %%
MAE_NP = pd.DataFrame(columns=['MAE','sMAPE(%)'], index=NP.index)
for date in NP.index:
    MAE_NP.loc[date]['RMSE'] = RMSE(pd.Series(NP.loc[date]['DNN 1']), pd.Series(NP.loc[date]['Real price']))
    MAE_NP.loc[date]['MAE'] = MAE(pd.Series(NP.loc[date]['DNN 1']), pd.Series(NP.loc[date]['Real price']))
    MAE_NP.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(NP.loc[date]['DNN 1']), pd.Series(NP.loc[date]['Real price'])) * 100

# %%
print(f"Overall MAE : {MAE(NP['DNN 1'], NP['Real price'])}")
# Out:
# Overall MAE : 1.5872619102822583

# %%
print(f"Overall sMAPE : {sMAPE(NP['DNN 1'], NP['Real price']) * 100}")
# Out:
# Overall sMAPE : 4.714884901352434

# %%
print(f"Overall RMSE : {RMSE(NP['DNN 1'], NP['Real price'])}")
# Out:
# Overall RMSE : 2.903248470854296

# %% [markdown]
# ### NP_NGBOOST_MAE_MAPE

# %%
NGBoost_NP = pd.read_csv('ngboost_NP.csv', index_col=[0])
NGBoost_NP.dropna(inplace=True)
NGBoost_NP_m = NGBoost_NP.drop(['h0_sd', 'h1_sd', 'h2_sd', 'h3_sd',
     'h4_sd', 'h5_sd', 'h6_sd', 'h7_sd',
       'h8_sd', 'h9_sd',  'h10_sd',  'h11_sd',
        'h12_sd',  'h13_sd',  'h14_sd', 
       'h15_sd',  'h16_sd',  'h17_sd',  'h18_sd',
        'h19_sd',  'h20_sd',  'h21_sd', 
       'h22_sd',  'h23_sd', 'RMSE'],axis=1)

# %%
df1 = pd.read_csv('df_testNP30.csv', index_col=[0])

# %%
df1
# Out:
#                   Price  Exogenous 1  Exogenous 2
# Date
# 26/12/2017 00:00  25.82        41942         3817
# 26/12/2017 01:00  24.94        41236         3839
# 26/12/2017 02:00  23.81        41088         3796
# 26/12/2017 03:00  23.68        41089         3804
#  27.61046282,
#  27.97403558,
#  27.89407178,
#  28.12722802,
#  28.38619994,
#  28.34960069,
#  28.58953434,
#  28.67794903,
#  28.66288107,
#  28.61905792,
#  28.69850236,
#  28.70487715,
#  29.35997939,
#  31.17379593,
#  29.24463658,
#  28.40129212,
#  28.29892234,
#  28.17211564,
#  27.9806041,
#  28.14558036,
#  28.00397787,
#  27.84969797,
#  27.560354,
#  27.40679058,
#  27.560354,
#  27.87412828,
#  27.90679257,
#  27.85928499,
#  28.09296032,
#  28.41850133,
#  28.34960069,
#  28.58953434,
#  28.54111845,
#  28.50593097,
#  28.61905792,
#  28.66983215,
#  29.24463658,
#  30.94135146,
#  29.04760956,
#  28.76371507,
#  28.25141578,
#  28.0222393,
#  28.0086857,
#  27.83924424,
#  26.60036981,
#  26.58556494,
#  26.58556494,
#  26.58556494,
#  26.60036981,
#  26.56805654,
#  27.35875801,
#  31.42355804,
#  32.20676993,
#  32.15200431,
#  32.15200431,
#  32.10124657,
#  31.90404897,
#  31.8629803,
#  31.8629803,
#  32.07875905,
#  32.07875905,
#  32.07875905,
#  32.07875905,
#  31.82679584,
#  29.81513026,
#  27.90866361,
#  27.24384169,
#  26.96865995,
#  26.07832464,
#  26.57622485,
#  26.58556494,
#  26.58556494,
#  26.77634155,
#  27.21669437,
#  28.60955184,
#  32.28718792,
#  33.5613917,
#  33.59711911,
#  33.72276722,
#  33.67200948,
#  33.67200948,
#  32.69959298,
#  33.17580581,
#  33.74267577,
#  36.83685046,
#  37.06608302,
#  34.6936093,
#  32.73521427,
#  31.22945999,
#  29.45610821,
#  28.94700633,
#  28.59717528,
#  28.18559577,
#  28.22084683,
#  28.3430822,
#  28.33059343,
#  28.33610541,
#  28.60792605,
#  29.47588718,
#  35.0909716,
#  37.2143416,
#  36.53389825,
#  37.76082153,
#  37.58261057,
#  36.48314051,
#  34.14828576,
#  34.26412111,
#  37.16358386,
#  39.72585173,
#  39.85330495,
#  39.30682502,
#  34.41988379,
#  32.25551111,
#  30.36216561,
#  29.29422761,
#  28.98854696,
#  28.30783114,
#  28.34859418,
#  28.35338011,
#  28.34859418,
#  28.30783114,
#  28.58230353,
#  29.72856485,
#  35.52968915,
#  38.03044506,
#  37.93577454,
#  38.30793932,
#  39.65055843,
#  38.9870434,
#  38.42513853,
#  38.40821021,
#  39.61614228,
#  41.75938344,
#  41.81072792,
#  40.35866591,
#  37.02525074,
#  35.2343291,
#  31.72935313,
#  30.24144232,
#  29.66859288,
#  28.55872776,
#  28.5994908,
#  28.5994908,
#  28.5994908,
#  28.55872776,
#  28.8514521,
#  30.70461949,
#  38.34055681,
#  41.72614619,
#  41.72614619,
#  41.72614619,
#  40.24072911,
#  38.8691066,
#  36.98011043,
#  36.86588296,
#  36.84895464,
#  38.81776213,
#  39.78086153,
#  37.32958496,
#  34.75029665,
#  30.93338087,
#  29.91386045,
#  29.26227379,
#  29.04968305,
#  28.31519468,
#  28.30714674,
#  28.35044575,
#  28.35044575,
#  28.35044575,
#  28.42236571,
#  28.18404676,
#  28.34493988,
#  28.75175505,
#  29.0757352,
#  29.39567332,
#  29.76599896,
#  29.46355594,
#  29.46355594,
#  29.46355594,
#  29.76599896,
#  31.58650924,
#  34.19376375,
#  33.69221355,
#  29.76599896,
#  29.08775003,
#  28.8536557,
#  28.62802753,
#  28.63128303,
#  28.54750748,
#  28.54199551,
#  28.54199551,
#  28.54199551,
#  28.54199551,
#  28.54199551,
#  28.41635955,
#  28.63128303,
#  28.62802753,
#  28.8536557,
#  29.20087698,
#  29.76599896,
#  29.46355594,
#  29.46355594,
#  29.46355594,
#  30.68878779,
#  33.69221355,
#  35.2408681,
#  34.64727213,
#  33.2659521,
#  30.13002805,
#  29.08653408,
#  28.62043247,
#  28.53479635,
#  28.40768222,
#  28.46211232,
#  28.11281203,
#  28.01901364,
#  28.2054788,
#  28.60205486,
#  29.63208704,
#  36.21690724,
#  35.95440897,
#  35.67344938,
#  35.95440897,
#  36.37004589,
#  36.37004589,
#  36.49569399,
#  36.53073899,
#  36.56636028,
#  36.76144283,
#  37.22681294,
#  37.08780563,
#  38.96384423,
#  35.32005103,
#  34.13529213,
#  29.95727895,
#  29.59685428,
#  28.58182697,
#  28.64829695,
#  28.58508247,
#  28.58508247,
#  28.55826177,
#  28.92571034,
#  34.08894188,
#  39.35758276,
#  37.07755096,
#  36.58149673,
#  36.54645173,
#  36.49569399,
#  36.37004589,
#  34.91798388,
#  34.7140875,
#  35.62269164,
#  35.29483613,
#  32.99757245,
#  32.60847752,
#  32.01728603,
#  29.97191234,
#  27.98591674,
#  27.32109483,
#  27.06570508,
#  26.11908769,
#  26.10428281,
#  25.9799452,
#  26.46122733,
#  26.58556494,
#  27.25697379,
#  28.50718206,
#  31.45410898,
#  31.56617583,
#  30.65649887,
#  30.31727059,
#  30.07602267,
#  29.88498843,
#  29.38343823,
#  29.38343823,
#  29.88498843,
#  30.70510687,
#  30.81933434,
#  30.07602267,
#  28.10735634,
#  27.42346461,
#  27.19428812,
#  27.40493336,
#  27.4366676,
#  25.50564315,
#  25.66689136,
#  25.66689136,
#  25.66689136,
#  26.14817348,
#  26.79186413,
#  27.82691922,
#  28.73496972,
#  30.13988617,
#  30.2445072,
#  28.93224085,
#  28.88148311,
#  28.68421198,
#  28.68421198,
#  29.29330629,
#  29.50984509,
#  31.06727635,
#  31.9562813,
#  31.40615601,
#  30.08841852,
#  29.3819493,
#  28.99806746,
#  28.75713797,
#  28.91818882]

# %%
NGB_NP['Predicted'] = temp1

# %%
NGB_NP.reset_index(inplace=True)
df1.reset_index(inplace=True)
NGB_NP['Real Price'] = df1['Price']
NGB_NP.set_index('index',inplace=True)
df1.set_index('Date',inplace=True)

# %%
MAE_NGB_NP = pd.DataFrame(columns=['RMSE', 'MAE','sMAPE(%)'], index=NGB_NP.index)
for date in NGB_NP.index:
    MAE_NGB_NP.loc[date]['RMSE'] = RMSE(pd.Series(NGB_NP.loc[date]['Predicted']), pd.Series(NGB_NP.loc[date]['Real Price']))
    MAE_NGB_NP.loc[date]['MAE'] = MAE(pd.Series(NGB_NP.loc[date]['Predicted']), pd.Series(NGB_NP.loc[date]['Real Price']))
    MAE_NGB_NP.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(NGB_NP.loc[date]['Predicted']), pd.Series(NGB_NP.loc[date]['Real Price'])) * 100

# %%
#NGBOOST PJM RMSE
print(f"Overall RMSE : {RMSE(NGB_NP['Predicted'], NGB_NP['Real Price'])}")
# Out:
# Overall RMSE : 4.589771168874722

# %%
#NGBOOST PJM MAE
print(f"Overall MAE : {MAE(NGB_NP['Predicted'], NGB_NP['Real Price'])}")
# Out:
# Overall MAE : 2.9515584553091396

# %%
#NGBOOST PJM MAPE
print(f"Overall sMAPE : {sMAPE(NGB_NP['Predicted'], NGB_NP['Real Price']) * 100} %")
# Out:
# Overall sMAPE : 8.451156083624225 %

# %% [markdown]
# # FR LEAR, DNN, NGBOOST

# %% [markdown]
# ### FR_LEAR_MAE_MAPE

# %%
FR
# Out:
#                      Real price      DNN 1  LEAR 56
# 2015-04-01 00:00:00       36.26  37.908104  38.9034
# 2015-04-01 01:00:00       32.28  34.774220  33.6675
# 2015-04-01 02:00:00       27.63  30.165806  29.7656
# 2015-04-01 03:00:00       23.94  24.531939  25.5819
# 2015-04-01 04:00:00       15.69  22.675518  22.3733
# ...                         ...        ...      ...
# 2015-03-02 19:00:00       68.71  75.608505  61.6084
# 2015-03-02 20:00:00       61.75  62.047821  55.5862
# 2015-03-02 21:00:00       53.17  51.751099  49.9943
# 2015-03-02 22:00:00       51.80  52.766350  50.5059
# 2015-03-02 23:00:00       46.98  50.929592  49.8164
#
# [744 rows x 3 columns]

# %%
MAE_FR = pd.DataFrame(columns=['RMSE', 'MAE','sMAPE(%)'], index=FR.index)
for date in MAE_FR.index:
    MAE_FR.loc[date]['RMSE'] = RMSE(pd.Series(FR.loc[date]['LEAR 56']), pd.Series(FR.loc[date]['Real price']))
    MAE_FR.loc[date]['MAE'] = MAE(pd.Series(FR.loc[date]['LEAR 56']), pd.Series(FR.loc[date]['Real price']))
    MAE_FR.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(FR.loc[date]['LEAR 56']), pd.Series(FR.loc[date]['Real price'])) * 100

# %%
MAE_FR
# Out:
#                        RMSE     MAE   sMAPE(%)
# 2015-04-01 00:00:00  2.6434  2.6434   7.033742
# 2015-04-01 01:00:00  1.3875  1.3875   4.207893
# 2015-04-01 02:00:00  2.1356  2.1356   7.441685
# 2015-04-01 03:00:00  1.6419  1.6419   6.631006
# 2015-04-01 04:00:00  6.6833  6.6833  35.116766
# ...                     ...     ...        ...
# 2015-03-02 19:00:00  7.1016  7.1016  10.898845
# 2015-03-02 20:00:00  6.1638  6.1638  10.506221
# 2015-03-02 21:00:00  3.1757  3.1757   6.156587
# 2015-03-02 22:00:00  1.2941  1.2941   2.529864
# 2015-03-02 23:00:00  2.8364  2.8364   5.860549
#
# [744 rows x 3 columns]

# %%
print(f"Overall MAE : {MAE(FR['LEAR 56'], FR['Real price'])}")
# Out:
# Overall MAE : 3.6409138440860214

# %%
print(f"Overall sMAPE : {sMAPE(FR['LEAR 56'], FR['Real price']) * 100} %")
# Out:
# Overall sMAPE : 10.136066936173954 %

# %%
print(f"Overall RMSE : {RMSE(FR['LEAR 56'], FR['Real price'])}")
# Out:
# Overall RMSE : 4.997590983945079

# %% [markdown]
# ### FR_DNN_MAE_MAPE

# %%
MAE_FR = pd.DataFrame(columns=['MAE','sMAPE(%)'], index=FR.index)
for date in FR.index:
    MAE_FR.loc[date]['RMSE'] = RMSE(pd.Series(FR.loc[date]['DNN 1']), pd.Series(FR.loc[date]['Real price']))
    MAE_FR.loc[date]['MAE'] = MAE(pd.Series(FR.loc[date]['DNN 1']), pd.Series(FR.loc[date]['Real price']))
    MAE_FR.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(FR.loc[date]['DNN 1']), pd.Series(FR.loc[date]['Real price'])) * 100

# %%
print(f"Overall MAE : {MAE(FR['DNN 1'], FR['Real price'])}")
# Out:
# Overall MAE : 3.492987625467742

# %%
print(f"Overall sMAPE : {sMAPE(FR['DNN 1'], FR['Real price']) * 100} %")
# Out:
# Overall sMAPE : 9.197918358127502 %

# %% [markdown]
# ### FR_NGBOOST_MAE_MAPE

# %%
MM  = pd.read_csv('FR_DATA.csv', index_col=[0])

# %%
MM
# Out:
#                   Predicted  Real Price
# Date
# 01/12/2016 00:00  44.463552       72.00
# 01/12/2016 01:00  39.963504       65.80
# 01/12/2016 02:00  38.171424       59.99
# 01/12/2016 03:00  34.852367       50.69
# 01/12/2016 04:00  32.619534       52.58
# ...                     ...         ...
# 31/12/2016 19:00  50.009299       69.72
# 31/12/2016 20:00  48.912822       57.10
# 31/12/2016 21:00  44.061156       54.49
# 31/12/2016 22:00  40.405223       54.95
# 31/12/2016 23:00  47.366881       61.19
#
# [744 rows x 2 columns]

# %%
MAE_NGB_FR = pd.DataFrame(columns=['MAE','sMAPE(%)'], index=MM.index)
for date in MM.index:
    MM.loc[date]['RMSE'] = RMSE(pd.Series(MM.loc[date]['Predicted']), pd.Series(MM.loc[date]['Real Price']))
    MM.loc[date]['MAE'] = MAE(pd.Series(MM.loc[date]['Predicted']), pd.Series(MM.loc[date]['Real Price']))
    MM.loc[date]['sMAPE(%)'] = sMAPE(pd.Series(MM.loc[date]['Predicted']), pd.Series(MM.loc[date]['Real Price'])) * 100

# %%
#NGBOOST FR MAE
print(f"Overall MAE : {MAE(MM['Predicted'], MM['Real Price'])}")
# Out:
# Overall MAE : 14.890192014395161

# %%
#NGBOOST FR MAPE
print(f"Overall sMAPE : {sMAPE(MM['Predicted'], MM['Real Price']) * 100} %")
# Out:
# Overall sMAPE : 28.618586036865622 %

# %%
#NGBOOST FR RMSE
print(f"Overall RMSE : {RMSE(MM['Predicted'], MM['Real Price'])}")
# Out:
# Overall RMSE : 19.934676222291863
